# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1.car_crashes

# %%
car=pd.read_csv('car_crashes.csv')
car
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
car.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
car['total'].var()
# Out:
# 16.990901960784313

# %%
car['speeding'].var()
# Out:
# 4.071303320784313

# %%
car['speeding'].std()
# Out:
# 2.0177470903917354

# %%
car['alcohol'].var()
# Out:
# 2.989900612549019

# %%
sns.boxplot(car['speeding'])
# Out:
# <Axes: >

# %%
sns.boxplot(car['no_previous'])
# Out:
# <Axes: >

# %% [markdown]
# 2.anagrams

# %%
anagrams=pd.read_csv('anagrams.csv',index_col=0)
anagrams
# Out:
#           attnr  num1  num2  num3
# subidr
# 1       divided     2   4.0     7
# 2       divided     3   4.0     5
# 3       divided     3   5.0     6
# 4       divided     5   7.0     5
# 5       divided     4   5.0     8
# 6       divided     5   5.0     6
# 7       divided     5   4.5     6
# 8       divided     5   7.0     8
# 9       divided     2   3.0     7
# 10      divided     6   5.0     6
# 11      focused     6   5.0     6
# 12      focused     8   9.0     8
# 13      focused     6   5.0     9
# 14      focused     8   8.0     7
# 15      focused     8   8.0     7
# 16      focused     6   8.0     7
# 17      focused     7   7.0     6
# 18      focused     7   8.0     6
# 19      focused     5   6.0     6
# 20      focused     6   6.0     5

# %%
anagrams.describe()
# Out:
#             num1      num2       num3
# count  20.000000  20.00000  20.000000
# mean    5.350000   5.97500   6.550000
# std     1.843195   1.67391   1.099043
# min     2.000000   3.00000   5.000000
# 25%     4.750000   5.00000   6.000000
# 50%     5.500000   5.50000   6.000000
# 75%     6.250000   7.25000   7.000000
# max     8.000000   9.00000   9.000000

# %%
plt.boxplot(anagrams['num2'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dcf5e5e740>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dcf5e5ec80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1dcf5e5e5c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dcf5e5f1c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dcf5e5f460>],
#  'means': []}

# %%
sns.distplot(anagrams['num1'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3616\4004697710.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(anagrams['num1'])
# <Axes: xlabel='num1', ylabel='Density'>

# %%
sns.distplot(anagrams['num2'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3616\2500197302.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(anagrams['num2'])
# <Axes: xlabel='num2', ylabel='Density'>

# %%
sns.distplot(anagrams['num3'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3616\34407755.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(anagrams['num3'])
# <Axes: xlabel='num3', ylabel='Density'>

# %% [markdown]
# 3.anscombe

# %%
anscombe=pd.read_csv("anscombe.csv")
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
anscombe.describe()
# Out:
#                x          y
# count  44.000000  44.000000
# mean    9.000000   7.500682
# std     3.198837   1.958925
# min     4.000000   3.100000
# 25%     7.000000   6.117500
# 50%     8.000000   7.520000
# 75%    11.000000   8.747500
# max    19.000000  12.740000

# %%
sns.boxplot(anscombe['x'])
# Out:
# <Axes: >

# %%
sns.boxplot(anscombe['y'])
# Out:
# <Axes: >

# %%
plt.boxplot(anscombe['x'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dcf71078e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dcf715aad0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1dcf715a890>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dcf715b010>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dcf715b2b0>],
#  'means': []}

# %% [markdown]
# 4.attention

# %%
attention=pd.read_csv("attention.csv",index_col=0)
attention
# Out:
#     subject attention  solutions  score
# 0         1   divided          1    2.0
# 1         2   divided          1    3.0
# 2         3   divided          1    3.0
# 3         4   divided          1    5.0
# 4         5   divided          1    4.0
# 5         6   divided          1    5.0
# 6         7   divided          1    5.0
# 7         8   divided          1    5.0
# 8         9   divided          1    2.0
# 9        10   divided          1    6.0
# 10       11   focused          1    6.0
# 11       12   focused          1    8.0
# 12       13   focused          1    6.0
# 13       14   focused          1    8.0
# 14       15   focused          1    8.0
# 15       16   focused          1    6.0
# 16       17   focused          1    7.0
# 17       18   focused          1    7.0
# 18       19   focused          1    5.0
# 19       20   focused          1    6.0
# 20        1   divided          2    4.0
# 21        2   divided          2    4.0
# ...

# %%
attention.describe()
# Out:
#          subject  solutions      score
# count  60.000000  60.000000  60.000000
# mean   10.500000   2.000000   5.958333
# std     5.814943   0.823387   1.621601
# min     1.000000   1.000000   2.000000
# 25%     5.750000   1.000000   5.000000
# 50%    10.500000   2.000000   6.000000
# 75%    15.250000   3.000000   7.000000
# max    20.000000   3.000000   9.000000

# %%
sns.boxplot(attention['score'])
# Out:
# <Axes: >
